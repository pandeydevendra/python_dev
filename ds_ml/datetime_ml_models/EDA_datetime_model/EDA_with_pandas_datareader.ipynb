# %% [markdown]
# ## Assignments;
#
# 1. Read the Microsoft Data using pandas_datareader.
#
# 2. Get the maximum price of the share from 2017 to 2022.
#
# 3. Which is the date of the highest price of the stock?
#
# 4. Which is the date of the lowest price of the stock?

# %%
import pandas_datareader as pdr
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline

# %%
df_msft = pdr.get_data_yahoo('MSFT')

# %%
df_msft
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-06-16   70.029999   69.220001   69.730003   70.000000  48345100.0
# 2017-06-19   70.940002   70.349998   70.500000   70.870003  23798300.0
# 2017-06-20   70.870003   69.870003   70.820000   69.910004  21512200.0
# 2017-06-21   70.620003   69.940002   70.209999   70.269997  19891100.0
# 2017-06-22   70.589996   69.709999   70.540001   70.260002  22965700.0
# ...                ...         ...         ...         ...         ...
# 2022-06-09  272.709991  264.630005  267.779999  264.790009  26439700.0
# 2022-06-10  260.579987  252.529999  260.579987  252.990005  31422800.0
# 2022-06-13  249.020004  241.529999  245.110001  242.259995  46135800.0
# 2022-06-14  245.740005  241.509995  243.860001  244.490005  28651500.0
# 2022-06-15  255.300003  246.419998  248.309998  251.759995  33073500.0
#
#              Adj Close
# Date
# 2017-06-16   65.565765
# 2017-06-19   66.380653
# 2017-06-20   65.481468
# ...

# %%
df_msft.plot(figsize=(16,8))

# %%
df_msft['Volume']
# Out:
# Date
# 2017-06-16    48345100.0
# 2017-06-19    23798300.0
# 2017-06-20    21512200.0
# 2017-06-21    19891100.0
# 2017-06-22    22965700.0
#                  ...
# 2022-06-09    26439700.0
# 2022-06-10    31422800.0
# 2022-06-13    46135800.0
# 2022-06-14    28651500.0
# 2022-06-15    33073500.0
# Name: Volume, Length: 1259, dtype: float64

# %%
df_msft.drop(columns='Volume')
# Out:
#                   High         Low        Open       Close   Adj Close
# Date
# 2017-06-16   70.029999   69.220001   69.730003   70.000000   65.565765
# 2017-06-19   70.940002   70.349998   70.500000   70.870003   66.380653
# 2017-06-20   70.870003   69.870003   70.820000   69.910004   65.481468
# 2017-06-21   70.620003   69.940002   70.209999   70.269997   65.818649
# 2017-06-22   70.589996   69.709999   70.540001   70.260002   65.809303
# ...                ...         ...         ...         ...         ...
# 2022-06-09  272.709991  264.630005  267.779999  264.790009  264.790009
# 2022-06-10  260.579987  252.529999  260.579987  252.990005  252.990005
# 2022-06-13  249.020004  241.529999  245.110001  242.259995  242.259995
# 2022-06-14  245.740005  241.509995  243.860001  244.490005  244.490005
# 2022-06-15  255.300003  246.419998  248.309998  251.759995  251.759995
#
# [1259 rows x 5 columns]

# %%
df_msft.drop(columns='Volume').plot(figsize=(16,8))

# %%
# 2. Get the maximum price of the share from 2017 to 2022.

# %%
df_msft.max()
# Out:
# High         3.496700e+02
# Low          3.422000e+02
# Open         3.446200e+02
# Close        3.431100e+02
# Volume       1.112421e+08
# Adj Close    3.416064e+02
# dtype: float64

# %%
df_msft['High'].max()
# Out:
# 349.6700134277344

# %%
## use resampling on yearly basis:

# %%
df_msft.resample(rule='Y')

# %%
df_msft.resample(rule='A').max()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2017-12-31   87.500000   86.230003   87.120003   86.849998   71066700.0
# 2018-12-31  116.180000  114.930000  115.419998  115.610001  111242100.0
# 2019-12-31  159.550003  158.220001  159.449997  158.960007   55636400.0
# 2020-12-31  232.860001  227.350006  229.270004  231.649994   97012700.0
# 2021-12-31  349.670013  342.200012  344.619995  343.109985   69870600.0
# 2022-12-31  338.000000  329.779999  335.350006  334.750000   90428900.0
#
#              Adj Close
# Date
# 2017-12-31   82.192528
# 2018-12-31  110.825478
# 2019-12-31  155.302597
# 2020-12-31  228.120407
# 2021-12-31  341.606384
# 2022-12-31  333.283020

# %%
df_msft.resample(rule='Y').max()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2017-12-31   87.500000   86.230003   87.120003   86.849998   71066700.0
# 2018-12-31  116.180000  114.930000  115.419998  115.610001  111242100.0
# 2019-12-31  159.550003  158.220001  159.449997  158.960007   55636400.0
# 2020-12-31  232.860001  227.350006  229.270004  231.649994   97012700.0
# 2021-12-31  349.670013  342.200012  344.619995  343.109985   69870600.0
# 2022-12-31  338.000000  329.779999  335.350006  334.750000   90428900.0
#
#              Adj Close
# Date
# 2017-12-31   82.192528
# 2018-12-31  110.825478
# 2019-12-31  155.302597
# 2020-12-31  228.120407
# 2021-12-31  341.606384
# 2022-12-31  333.283020

# %%
df_msft.resample(rule='YS').max()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2017-01-01   87.500000   86.230003   87.120003   86.849998   71066700.0
# 2018-01-01  116.180000  114.930000  115.419998  115.610001  111242100.0
# 2019-01-01  159.550003  158.220001  159.449997  158.960007   55636400.0
# 2020-01-01  232.860001  227.350006  229.270004  231.649994   97012700.0
# 2021-01-01  349.670013  342.200012  344.619995  343.109985   69870600.0
# 2022-01-01  338.000000  329.779999  335.350006  334.750000   90428900.0
#
#              Adj Close
# Date
# 2017-01-01   82.192528
# 2018-01-01  110.825478
# 2019-01-01  155.302597
# 2020-01-01  228.120407
# 2021-01-01  341.606384
# 2022-01-01  333.283020

# %%
# 3. Which is the date of the highest price of the stock?

# %%
df_msft['High'].max()
# Out:
# 349.6700134277344

# %%
df_msft[df_msft['High'] == df_msft['High'].max()]
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-11-22  349.670013  339.549988  344.619995  339.829987  31031100.0
#
#              Adj Close
# Date
# 2021-11-22  338.340729

# %%
df_msft[df_msft['High'] == df_msft['High'].max()].index
# Out:
# DatetimeIndex(['2021-11-22'], dtype='datetime64[ns]', name='Date', freq=None)

# %%
# 4. Which is the date of the lowest price of the stock?

# %%
df_msft['High'].min()
# Out:
# 68.77999877929688

# %%
df_msft[df_msft['High']==df_msft['High'].min()].index
# Out:
# DatetimeIndex(['2017-07-06'], dtype='datetime64[ns]', name='Date', freq=None)

# %%
# few more

# %%
df_msft.High.plot(figsize=(10,4))

# %%
df_msft.Volume.plot(figsize=(16,6))

# %%
df_msft['High'].resample(rule='QS')

# %%
df_msft['High'].resample(rule='QS').mean()
# Out:
# Date
# 2017-04-01     70.445454
# 2017-07-01     73.452222
# 2017-10-01     82.503651
# 2018-01-01     92.538197
# 2018-04-01     97.776250
# 2018-07-01    109.083016
# 2018-10-01    108.823651
# 2019-01-01    109.821639
# 2019-04-01    127.823810
# 2019-07-01    138.560313
# 2019-10-01    147.661250
# 2020-01-01    167.361775
# 2020-04-01    183.630793
# 2020-07-01    212.650313
# 2020-10-01    217.154531
# 2021-01-01    234.408361
# 2021-04-01    255.783492
# 2021-07-01    292.806718
# 2021-10-01    326.681877
# 2022-01-01    305.124033
# 2022-04-01    278.658267
# Freq: QS-JAN, Name: High, dtype: float64

# %%
df_msft['High'].resample(rule='QS').mean().plot(figsize=(14,5))

# %%
df_msft['High'].resample(rule='QS').max().plot(kind='bar', figsize=(14,5))

# %%
df_msft['Volume'].resample(rule='QS').max().plot(kind='bar', figsize=(14,5))

# %%
df_msft['High'].resample(rule='AS').max().plot(kind='bar', figsize=(14,5))

# %%
df_msft['High'].resample(rule='AS').max().plot(kind='pie',figsize=(10,5))

# %%
df_msft['High'].resample(rule='AS').max().plot(kind='pie')

# %%
df_msft['High'].resample(rule='AS').max().plot(kind='pie', radius=1)

# %%
df_msft['High'].resample(rule='AS').max().plot(kind='pie', radius=1.5, legend=True)
