# %%
import json
import requests

# %%
if __name__ == "__main__":
    url = 'https://www.last.fm/api/show/album.getInfo'
    data = requests.get(url).text
    print(type(data))
    print(data)
# Out:
# <class 'str'>
#
#
#
#
#
#
# <!doctype html>
# <html
#     lang="en"
#     class="
#         no-js
#         playbar-masthead-release-shim
#         youtube-provider-not-ready
#     "
# >
#     <head>
#         <meta charset="utf-8">
# ...

# %%
#data['artist']

# %%
if __name__ == "__main__":
    url = 'https://www.last.fm/api/show/album.getInfo'
    data = requests.get(url).text
    data = json.loads(data)
    print(type(data))
    print(data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-14-4de071ad7678> in <module>
#       2     url = 'https://www.last.fm/api/show/album.getInfo'
#       3     data = requests.get(url).text
# ----> 4     data = json.loads(data)
#       5     print(type(data))
#       6     print(data)
#
# /usr/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /usr/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
# ...

# %%
if __name__ == "__main__":
    url = 'http://ws.audioscrobbler.com/2.0/?method=album.getinfo&api_key=YOUR_API_KEY&artist=Cher&album=Believe&format=json'
    data = requests.get(url).text
    print(type(data))
    print(data)
# Out:
# <class 'str'>
# {"message":"Invalid API key - You must be granted a valid key by last.fm","error":10}
