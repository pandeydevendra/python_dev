# %%
import pandas as pd
import pandasql as pdsql

# %% [markdown]
# #### it's pandasql i.e panda sql not pandas sql

# %%
filename = 'aadhaar_data.csv'
aadhaar_data = pd.read_csv(filename)

# %%
query = "SELECT * FROM aadhaar_data;"
results = pdsql.sqldf(query)

# %% [markdown]
# #### The pandasql package allows us to perform queries on dataframes using the SQLite syntax.

# %%
results
# Out:
#                     Registrar             Enrolment Agency             State  \
# 0              Allahabad Bank            Tera Software Ltd         Jharkhand
# 1              Allahabad Bank            Tera Software Ltd         Jharkhand
# 2              Allahabad Bank  Vakrangee Softwares Limited           Gujarat
# 3              Allahabad Bank  Vakrangee Softwares Limited  Himachal Pradesh
# 4              Allahabad Bank  Vakrangee Softwares Limited    Madhya Pradesh
# ...                       ...                          ...               ...
# 119993  Central Bank of India         IAP COMPANY Pvt. Ltd       Maharashtra
# 119994  Central Bank of India         IAP COMPANY Pvt. Ltd       Maharashtra
# 119995  Central Bank of India         IAP COMPANY Pvt. Ltd       Maharashtra
# 119996  Central Bank of India         IAP COMPANY Pvt. Ltd       Maharashtra
# 119997  Central Bank of India         IAP COMPANY Pvt. Ltd       Maharashtra
#
# ...

# %%
query = "SELECT * FROM aadhaar_data LIMIT 20;"
results = pdsql.sqldf(query)
results
# Out:
#          Registrar             Enrolment Agency             State    District  \
# 0   Allahabad Bank            Tera Software Ltd         Jharkhand      Ranchi
# 1   Allahabad Bank            Tera Software Ltd         Jharkhand      Ranchi
# 2   Allahabad Bank  Vakrangee Softwares Limited           Gujarat       Surat
# 3   Allahabad Bank  Vakrangee Softwares Limited  Himachal Pradesh      Kangra
# 4   Allahabad Bank  Vakrangee Softwares Limited    Madhya Pradesh  Chhindwara
# 5   Allahabad Bank  Vakrangee Softwares Limited       Maharashtra  Ahmadnagar
# 6   Allahabad Bank  Vakrangee Softwares Limited       Maharashtra  Ahmadnagar
# 7   Allahabad Bank  Vakrangee Softwares Limited       Maharashtra  Ahmadnagar
# 8   Allahabad Bank  Vakrangee Softwares Limited       Maharashtra  Ahmadnagar
# 9   Allahabad Bank  Vakrangee Softwares Limited       Maharashtra  Ahmadnagar
# 10  Allahabad Bank  Vakrangee Softwares Limited       Maharashtra  Ahmadnagar
# ...

# %%
query = "SELECT Registrar, State, District, age FROM aadhaar_data LIMIT 25;"
results = pdsql.sqldf(query)
results
# Out:
#          Registrar             State     District  Age
# 0   Allahabad Bank         Jharkhand       Ranchi   63
# 1   Allahabad Bank         Jharkhand       Ranchi   36
# 2   Allahabad Bank           Gujarat        Surat   10
# 3   Allahabad Bank  Himachal Pradesh       Kangra   44
# 4   Allahabad Bank    Madhya Pradesh   Chhindwara   35
# 5   Allahabad Bank       Maharashtra   Ahmadnagar   28
# 6   Allahabad Bank       Maharashtra   Ahmadnagar   31
# 7   Allahabad Bank       Maharashtra   Ahmadnagar    9
# 8   Allahabad Bank       Maharashtra   Ahmadnagar   35
# 9   Allahabad Bank       Maharashtra   Ahmadnagar   33
# 10  Allahabad Bank       Maharashtra   Ahmadnagar   56
# 11  Allahabad Bank       Maharashtra   Ahmadnagar   64
# 12  Allahabad Bank       Maharashtra   Ahmadnagar   55
# 13  Allahabad Bank       Maharashtra   Ahmadnagar   31
# 14  Allahabad Bank       Maharashtra   Ahmadnagar   35
# 15  Allahabad Bank       Maharashtra   Ahmadnagar   49
# ...

# %%
query = "SELECT * FROM aadhaar_data WHERE state = 'Gujarat';"
results = pdsql.sqldf(query)
results
# Out:
#                 Registrar             Enrolment Agency    State     District  \
# 0          Allahabad Bank  Vakrangee Softwares Limited  Gujarat        Surat
# 1           Bank Of India   CHESSY CONSULTANTS PVT LTD  Gujarat    Ahmedabad
# 2           Bank Of India   CHESSY CONSULTANTS PVT LTD  Gujarat       Amreli
# 3           Bank Of India   CHESSY CONSULTANTS PVT LTD  Gujarat       Amreli
# 4           Bank Of India   CHESSY CONSULTANTS PVT LTD  Gujarat     Junagadh
# ..                    ...                          ...      ...          ...
# 80  Central Bank of India         IAP COMPANY Pvt. Ltd  Gujarat  Banaskantha
# 81  Central Bank of India         IAP COMPANY Pvt. Ltd  Gujarat  Banaskantha
# 82  Central Bank of India         IAP COMPANY Pvt. Ltd  Gujarat  Banaskantha
# 83  Central Bank of India         IAP COMPANY Pvt. Ltd  Gujarat      Kachchh
# 84  Central Bank of India         IAP COMPANY Pvt. Ltd  Gujarat        Patan
#
# ...

# %%
query = "SELECT DISTINCT(District), COUNT(Registrar) FROM aadhaar_data WHERE state = 'Gujarat' GROUP BY District;"
results = pdsql.sqldf(query)
results
# Out:
#           District  COUNT(Registrar)
# 0        Ahmedabad                10
# 1           Amreli                 4
# 2      Banaskantha                 4
# 3          Bharuch                 1
# 4         Jamnagar                 8
# 5         Junagadh                 3
# 6          Kachchh                 6
# 7         Mahesana                 2
# 8            Patan                 1
# 9           Rajkot                 4
# 10           Surat                 1
# 11  Surendra Nagar                 9
# 12        Vadodara                 4
# 13          Valsad                28

# %%
query = "SELECT DISTINCT(District), COUNT(*) FROM aadhaar_data WHERE state = 'Gujarat' GROUP BY District;"
results = pdsql.sqldf(query)
results
# Out:
#           District  COUNT(*)
# 0        Ahmedabad        10
# 1           Amreli         4
# 2      Banaskantha         4
# 3          Bharuch         1
# 4         Jamnagar         8
# 5         Junagadh         3
# 6          Kachchh         6
# 7         Mahesana         2
# 8            Patan         1
# 9           Rajkot         4
# 10           Surat         1
# 11  Surendra Nagar         9
# 12        Vadodara         4
# 13          Valsad        28

# %%
query = "SELECT DISTINCT(District), COUNT(*) FROM aadhaar_data GROUP BY District;"
results = pdsql.sqldf(query)
results
# Out:
#            District  COUNT(*)
# 0          Adilabad         1
# 1              Agra         9
# 2        Ahmadnagar       594
# 3       Ahmed Nagar       100
# 4         Ahmedabad        10
# ..              ...       ...
# 523  West Singhbhum      2122
# 524    West Tripura       374
# 525          Yadgir        81
# 526    Yamuna Nagar       788
# 527        Yavatmal       463
#
# [528 rows x 2 columns]

# %%
query = "SELECT District, COUNT(*) FROM aadhaar_data GROUP BY District;"
results = pdsql.sqldf(query)
results
# Out:
#            District  COUNT(*)
# 0          Adilabad         1
# 1              Agra         9
# 2        Ahmadnagar       594
# 3       Ahmed Nagar       100
# 4         Ahmedabad        10
# ..              ...       ...
# 523  West Singhbhum      2122
# 524    West Tripura       374
# 525          Yadgir        81
# 526    Yamuna Nagar       788
# 527        Yavatmal       463
#
# [528 rows x 2 columns]

# %%
query = "SELECT District, COUNT(*) FROM aadhaar_data WHERE age > 60 GROUP BY District;"
results = pdsql.sqldf(query)
results
# Out:
#            District  COUNT(*)
# 0        Ahmadnagar        73
# 1       Ahmed Nagar        19
# 2         Ahmedabad         1
# 3             Ajmer        39
# 4             Akola         3
# ..              ...       ...
# 250  West Singhbhum       154
# 251    West Tripura        20
# 252          Yadgir         8
# 253    Yamuna Nagar       106
# 254        Yavatmal        57
#
# [255 rows x 2 columns]

# %%
query = "SELECT State, COUNT(*) FROM aadhaar_data WHERE age > 60 GROUP BY State;"
results = pdsql.sqldf(query)
results
# Out:
#                State  COUNT(*)
# 0     Andhra Pradesh        47
# 1              Bihar        15
# 2         Chandigarh         2
# 3       Chhattisgarh         1
# 4              Delhi        48
# 5            Gujarat         2
# 6            Haryana       888
# 7   Himachal Pradesh         4
# 8          Jharkhand      1116
# 9          Karnataka       883
# 10            Kerala         1
# 11    Madhya Pradesh      3947
# 12       Maharashtra      1894
# 13            Odisha         2
# 14            Others         2
# 15        Puducherry         2
# 16            Punjab       722
# 17         Rajasthan       772
# 18        Tamil Nadu        19
# 19           Tripura        46
# 20     Uttar Pradesh        27
# 21       Uttarakhand         1
# 22       West Bengal         4

# %% [markdown]
# ####  for column; by replacing spaces with underscores and setting all characters to lowercaseaadhaar_data.rename(columns=lambda x: x.replace(' ', '_').lower(), inplace=True), so the

# %%
aadhaar_data = pd.read_csv(filename)
aadhaar_data.rename(columns=lambda x: x.replace(' ', '_').lower(), inplace=True)

# %%
aadhaar_solution = pdsql.sqldf(query.lower(), locals())
aadhaar_solution
# Out:
#                state  count(*)
# 0     Andhra Pradesh        47
# 1              Bihar        15
# 2         Chandigarh         2
# 3       Chhattisgarh         1
# 4              Delhi        48
# 5            Gujarat         2
# 6            Haryana       888
# 7   Himachal Pradesh         4
# 8          Jharkhand      1116
# 9          Karnataka       883
# 10            Kerala         1
# 11    Madhya Pradesh      3947
# 12       Maharashtra      1894
# 13            Odisha         2
# 14            Others         2
# 15        Puducherry         2
# 16            Punjab       722
# 17         Rajasthan       772
# 18        Tamil Nadu        19
# 19           Tripura        46
# 20     Uttar Pradesh        27
# 21       Uttarakhand         1
# 22       West Bengal         4

# %%
query = "SELECT * FROM aadhaar_data LIMIT 10;"
aadhaar_solution = pdsql.sqldf(query.lower(), locals())
aadhaar_solution
# Out:
#         registrar             enrolment_agency             state    district  \
# 0  Allahabad Bank            Tera Software Ltd         Jharkhand      Ranchi
# 1  Allahabad Bank            Tera Software Ltd         Jharkhand      Ranchi
# 2  Allahabad Bank  Vakrangee Softwares Limited           Gujarat       Surat
# 3  Allahabad Bank  Vakrangee Softwares Limited  Himachal Pradesh      Kangra
# 4  Allahabad Bank  Vakrangee Softwares Limited    Madhya Pradesh  Chhindwara
# 5  Allahabad Bank  Vakrangee Softwares Limited       Maharashtra  Ahmadnagar
# 6  Allahabad Bank  Vakrangee Softwares Limited       Maharashtra  Ahmadnagar
# 7  Allahabad Bank  Vakrangee Softwares Limited       Maharashtra  Ahmadnagar
# 8  Allahabad Bank  Vakrangee Softwares Limited       Maharashtra  Ahmadnagar
# 9  Allahabad Bank  Vakrangee Softwares Limited       Maharashtra  Ahmadnagar
#
#   sub_district pin_code gender  age  aadhaar_generated  enrolment_rejected  \
# ...

# %%
query = "SELECT registrar, enrolment_agency FROM aadhaar_data LIMIT 10;"
aadhaar_solution = pdsql.sqldf(query.lower(), locals())
aadhaar_solution
# Out:
#         registrar             enrolment_agency
# 0  Allahabad Bank            Tera Software Ltd
# 1  Allahabad Bank            Tera Software Ltd
# 2  Allahabad Bank  Vakrangee Softwares Limited
# 3  Allahabad Bank  Vakrangee Softwares Limited
# 4  Allahabad Bank  Vakrangee Softwares Limited
# 5  Allahabad Bank  Vakrangee Softwares Limited
# 6  Allahabad Bank  Vakrangee Softwares Limited
# 7  Allahabad Bank  Vakrangee Softwares Limited
# 8  Allahabad Bank  Vakrangee Softwares Limited
# 9  Allahabad Bank  Vakrangee Softwares Limited

# %%
query = "SELECT district, sum(aadhaar_generated) FROM aadhaar_data GROUP BY District;"
aadhaar_generated = pdsql.sqldf(query.lower(), locals())
aadhaar_generated
# Out:
#            district  sum(aadhaar_generated)
# 0          Adilabad                       1
# 1              Agra                       9
# 2        Ahmadnagar                     552
# 3       Ahmed Nagar                       0
# 4         Ahmedabad                       9
# ..              ...                     ...
# 523  West Singhbhum                    4170
# 524    West Tripura                     392
# 525          Yadgir                      69
# 526    Yamuna Nagar                    1586
# 527        Yavatmal                     469
#
# [528 rows x 2 columns]

# %%
query = "SELECT state, sum(aadhaar_generated) FROM aadhaar_data GROUP BY state;"
aadhaar_generated = pdsql.sqldf(query.lower(), locals())
aadhaar_generated
# Out:
#                      state  sum(aadhaar_generated)
# 0           Andhra Pradesh                     820
# 1        Arunachal Pradesh                       4
# 2                    Assam                      34
# 3                    Bihar                     622
# 4               Chandigarh                      31
# 5             Chhattisgarh                      28
# 6   Dadra and Nagar Haveli                       1
# 7                    Delhi                    1025
# 8                  Gujarat                      85
# 9                  Haryana                   19480
# 10        Himachal Pradesh                     129
# 11       Jammu and Kashmir                      49
# 12               Jharkhand                   25089
# 13               Karnataka                   14737
# 14                  Kerala                      29
# 15          Madhya Pradesh                   88557
# 16             Maharashtra                   20042
# ...

# %%
query = "SELECT sum(aadhaar_generated) FROM aadhaar_data;"
aadhaar_generated = pdsql.sqldf(query.lower(), locals())
aadhaar_generated
# Out:
#    sum(aadhaar_generated)
# 0                  193001

# %%
query = "SELECT sum(aadhaar_generated) FROM aadhaar_data WHERE aadhaar_generated = 1;"
aadhaar_generated = pdsql.sqldf(query.lower(), locals())
aadhaar_generated
# Out:
#    sum(aadhaar_generated)
# 0                   73269

# %%
query = "SELECT gender, sum(aadhaar_generated) FROM aadhaar_data GROUP BY gender;"
aadhaar_generated = pdsql.sqldf(query.lower(), locals())
aadhaar_generated
# Out:
#   gender  sum(aadhaar_generated)
# 0      F                   80895
# 1      M                  112106

# %%
query = "SELECT gender, state, sum(aadhaar_generated) FROM aadhaar_data GROUP BY gender, state;"
aadhaar_generated = pdsql.sqldf(query.lower(), locals())
aadhaar_generated
# Out:
#    gender                   state  sum(aadhaar_generated)
# 0       F          Andhra Pradesh                     368
# 1       F                   Assam                       9
# 2       F                   Bihar                     126
# 3       F              Chandigarh                      11
# 4       F            Chhattisgarh                       9
# 5       F  Dadra and Nagar Haveli                       1
# 6       F                   Delhi                     476
# 7       F                 Gujarat                      29
# 8       F                 Haryana                    9043
# 9       F        Himachal Pradesh                      28
# 10      F       Jammu and Kashmir                      11
# 11      F               Jharkhand                   11682
# 12      F               Karnataka                    6690
# 13      F                  Kerala                       6
# 14      F          Madhya Pradesh                   36147
# ...

# %%
query = "SELECT state, count(gender) FROM aadhaar_data where aadhaar_generated = 1 GROUP BY state;"
aadhaar_generated = pdsql.sqldf(query.lower(), locals())
aadhaar_generated
# Out:
#                      state  count(gender)
# 0           Andhra Pradesh            563
# 1        Arunachal Pradesh              4
# 2                    Assam             34
# 3                    Bihar            616
# 4               Chandigarh             29
# 5             Chhattisgarh             28
# 6   Dadra and Nagar Haveli              1
# 7                    Delhi            778
# 8                  Gujarat             81
# 9                  Haryana           4748
# 10        Himachal Pradesh            125
# 11       Jammu and Kashmir             49
# 12               Jharkhand           7395
# 13               Karnataka           7132
# 14                  Kerala             29
# 15          Madhya Pradesh          29156
# 16             Maharashtra           9651
# 17                 Manipur              3
# 18               Meghalaya              1
# 19                  Odisha            119
# 20                  Others             43
# ...

# %%
query = "SELECT state, sum(gender) FROM aadhaar_data where ('gender' = 'M' and aadhaar_generated = 1) GROUP BY state;"
aadhaar_generated = pdsql.sqldf(query.lower(), locals())
aadhaar_generated
# Out:
# Empty DataFrame
# Columns: [state, sum(gender)]
# Index: []
