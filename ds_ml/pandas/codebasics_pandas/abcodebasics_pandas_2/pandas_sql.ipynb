# %% [markdown]
# # <font color="purple"><h3 align="center">Dataframe and mysql database tutorial</h3></font>

# %%
import pandas as pd
import sqlalchemy

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://root:@localhost:3306/application')

# %% [markdown]
# Format of connection string is:
#
# mysql+pymysql://username:password@host:port/database_name
#
# Format of connection string for other databases
#
# https://pandas.pydata.org/pandas-docs/stable/io.html#engine-connection-examples

# %% [markdown]
# <img src="conn_string_format.JPG"/>

# %% [markdown]
# <h3 style="color:purple">Read entire table in a dataframe using <span style="color:blue">read_sql_table</span></h3>

# %%
df = pd.read_sql_table('customers',engine)
df
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3142, in _wrap_pool_connect
#     return fn()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 761, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 362, in __init__
#     self.__connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 605, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 599, in __connect
#     connection = pool._invoke_creator(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/create.py", line 578, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/default.py", line 584, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 353, in __init__
#     self.connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 633, in connect
#     self._request_authentication()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 907, in _request_authentication
#     auth_packet = self._read_packet()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.OperationalError: (1045, "Access denied for user 'root'@'localhost' (using password: NO)")
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-dc31362252c6>", line 1, in <module>
#     df = pd.read_sql_table('customers',engine)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pandas/io/sql.py", line 242, in read_sql_table
#     meta.reflect(only=[table_name], views=True)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/sql/schema.py", line 4656, in reflect
#     with inspection.inspect(bind)._inspection_context() as insp:
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/inspection.py", line 64, in inspect
#     ret = reg(subject)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py", line 182, in _engine_insp
#     return Inspector._construct(Inspector._init_engine, bind)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py", line 117, in _construct
#     init(self, bind)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py", line 128, in _init_engine
#     engine.connect().close()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3096, in connect
#     return self._connection_cls(self, close_with_result=close_with_result)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 92, in __init__
#     else engine.raw_connection()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3175, in raw_connection
#     return self._wrap_pool_connect(self.pool.connect, _connection)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3146, in _wrap_pool_connect
#     e, dialect, self
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 2005, in _handle_dbapi_exception_noconnection
#     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3142, in _wrap_pool_connect
#     return fn()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 761, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 362, in __init__
#     self.__connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 605, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 599, in __connect
#     connection = pool._invoke_creator(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/create.py", line 578, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/default.py", line 584, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 353, in __init__
#     self.connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 633, in connect
#     self._request_authentication()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 907, in _request_authentication
#     auth_packet = self._read_packet()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# sqlalchemy.exc.OperationalError: (pymysql.err.OperationalError) (1045, "Access denied for user 'root'@'localhost' (using password: NO)")
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OperationalError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3142, in _wrap_pool_connect
#     return fn()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 761, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 362, in __init__
#     self.__connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 605, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 599, in __connect
#     connection = pool._invoke_creator(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/create.py", line 578, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/default.py", line 584, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 353, in __init__
#     self.connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 633, in connect
#     self._request_authentication()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 907, in _request_authentication
#     auth_packet = self._read_packet()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.OperationalError: (1045, "Access denied for user 'root'@'localhost' (using password: NO)")
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-dc31362252c6>", line 1, in <module>
#     df = pd.read_sql_table('customers',engine)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pandas/io/sql.py", line 242, in read_sql_table
#     meta.reflect(only=[table_name], views=True)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/sql/schema.py", line 4656, in reflect
#     with inspection.inspect(bind)._inspection_context() as insp:
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/inspection.py", line 64, in inspect
#     ret = reg(subject)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py", line 182, in _engine_insp
#     return Inspector._construct(Inspector._init_engine, bind)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py", line 117, in _construct
#     init(self, bind)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py", line 128, in _init_engine
#     engine.connect().close()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3096, in connect
#     return self._connection_cls(self, close_with_result=close_with_result)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 92, in __init__
#     else engine.raw_connection()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3175, in raw_connection
#     return self._wrap_pool_connect(self.pool.connect, _connection)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3146, in _wrap_pool_connect
#     e, dialect, self
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 2005, in _handle_dbapi_exception_noconnection
#     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3142, in _wrap_pool_connect
#     return fn()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 761, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 362, in __init__
#     self.__connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 605, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 599, in __connect
#     connection = pool._invoke_creator(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/create.py", line 578, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/default.py", line 584, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 353, in __init__
#     self.connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 633, in connect
#     self._request_authentication()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 907, in _request_authentication
#     auth_packet = self._read_packet()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# sqlalchemy.exc.OperationalError: (pymysql.err.OperationalError) (1045, "Access denied for user 'root'@'localhost' (using password: NO)")
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OperationalError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3142, in _wrap_pool_connect
#     return fn()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 761, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 362, in __init__
#     self.__connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 605, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 599, in __connect
#     connection = pool._invoke_creator(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/create.py", line 578, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/default.py", line 584, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 353, in __init__
#     self.connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 633, in connect
#     self._request_authentication()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 907, in _request_authentication
#     auth_packet = self._read_packet()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.OperationalError: (1045, "Access denied for user 'root'@'localhost' (using password: NO)")
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-dc31362252c6>", line 1, in <module>
#     df = pd.read_sql_table('customers',engine)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pandas/io/sql.py", line 242, in read_sql_table
#     meta.reflect(only=[table_name], views=True)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/sql/schema.py", line 4656, in reflect
#     with inspection.inspect(bind)._inspection_context() as insp:
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/inspection.py", line 64, in inspect
#     ret = reg(subject)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py", line 182, in _engine_insp
#     return Inspector._construct(Inspector._init_engine, bind)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py", line 117, in _construct
#     init(self, bind)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py", line 128, in _init_engine
#     engine.connect().close()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3096, in connect
#     return self._connection_cls(self, close_with_result=close_with_result)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 92, in __init__
#     else engine.raw_connection()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3175, in raw_connection
#     return self._wrap_pool_connect(self.pool.connect, _connection)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3146, in _wrap_pool_connect
#     e, dialect, self
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 2005, in _handle_dbapi_exception_noconnection
#     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3142, in _wrap_pool_connect
#     return fn()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 761, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 362, in __init__
#     self.__connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 605, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 599, in __connect
#     connection = pool._invoke_creator(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/create.py", line 578, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/default.py", line 584, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 353, in __init__
#     self.connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 633, in connect
#     self._request_authentication()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 907, in _request_authentication
#     auth_packet = self._read_packet()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# sqlalchemy.exc.OperationalError: (pymysql.err.OperationalError) (1045, "Access denied for user 'root'@'localhost' (using password: NO)")
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OperationalError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3282, in run_ast_nodes
#     self.showtraceback()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1211, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory

# %% [markdown]
# **Read only selected columns**

# %%
df = pd.read_sql_table('customers', engine, columns=["name"])
df
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3142, in _wrap_pool_connect
#     return fn()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 761, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 362, in __init__
#     self.__connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 605, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 599, in __connect
#     connection = pool._invoke_creator(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/create.py", line 578, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/default.py", line 584, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 353, in __init__
#     self.connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 633, in connect
#     self._request_authentication()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 907, in _request_authentication
#     auth_packet = self._read_packet()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.OperationalError: (1045, "Access denied for user 'root'@'localhost' (using password: NO)")
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-b8a1bd42c923>", line 1, in <module>
#     df = pd.read_sql_table('customers', engine, columns=["name"])
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pandas/io/sql.py", line 242, in read_sql_table
#     meta.reflect(only=[table_name], views=True)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/sql/schema.py", line 4656, in reflect
#     with inspection.inspect(bind)._inspection_context() as insp:
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/inspection.py", line 64, in inspect
#     ret = reg(subject)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py", line 182, in _engine_insp
#     return Inspector._construct(Inspector._init_engine, bind)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py", line 117, in _construct
#     init(self, bind)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py", line 128, in _init_engine
#     engine.connect().close()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3096, in connect
#     return self._connection_cls(self, close_with_result=close_with_result)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 92, in __init__
#     else engine.raw_connection()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3175, in raw_connection
#     return self._wrap_pool_connect(self.pool.connect, _connection)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3146, in _wrap_pool_connect
#     e, dialect, self
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 2005, in _handle_dbapi_exception_noconnection
#     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3142, in _wrap_pool_connect
#     return fn()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 761, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 362, in __init__
#     self.__connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 605, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 599, in __connect
#     connection = pool._invoke_creator(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/create.py", line 578, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/default.py", line 584, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 353, in __init__
#     self.connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 633, in connect
#     self._request_authentication()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 907, in _request_authentication
#     auth_packet = self._read_packet()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# sqlalchemy.exc.OperationalError: (pymysql.err.OperationalError) (1045, "Access denied for user 'root'@'localhost' (using password: NO)")
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OperationalError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3142, in _wrap_pool_connect
#     return fn()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 761, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 362, in __init__
#     self.__connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 605, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 599, in __connect
#     connection = pool._invoke_creator(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/create.py", line 578, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/default.py", line 584, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 353, in __init__
#     self.connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 633, in connect
#     self._request_authentication()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 907, in _request_authentication
#     auth_packet = self._read_packet()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.OperationalError: (1045, "Access denied for user 'root'@'localhost' (using password: NO)")
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-b8a1bd42c923>", line 1, in <module>
#     df = pd.read_sql_table('customers', engine, columns=["name"])
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pandas/io/sql.py", line 242, in read_sql_table
#     meta.reflect(only=[table_name], views=True)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/sql/schema.py", line 4656, in reflect
#     with inspection.inspect(bind)._inspection_context() as insp:
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/inspection.py", line 64, in inspect
#     ret = reg(subject)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py", line 182, in _engine_insp
#     return Inspector._construct(Inspector._init_engine, bind)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py", line 117, in _construct
#     init(self, bind)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py", line 128, in _init_engine
#     engine.connect().close()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3096, in connect
#     return self._connection_cls(self, close_with_result=close_with_result)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 92, in __init__
#     else engine.raw_connection()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3175, in raw_connection
#     return self._wrap_pool_connect(self.pool.connect, _connection)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3146, in _wrap_pool_connect
#     e, dialect, self
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 2005, in _handle_dbapi_exception_noconnection
#     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3142, in _wrap_pool_connect
#     return fn()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 761, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 362, in __init__
#     self.__connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 605, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 599, in __connect
#     connection = pool._invoke_creator(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/create.py", line 578, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/default.py", line 584, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 353, in __init__
#     self.connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 633, in connect
#     self._request_authentication()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 907, in _request_authentication
#     auth_packet = self._read_packet()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# sqlalchemy.exc.OperationalError: (pymysql.err.OperationalError) (1045, "Access denied for user 'root'@'localhost' (using password: NO)")
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OperationalError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3142, in _wrap_pool_connect
#     return fn()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 761, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
# ERROR! Session/line number was not unique in database. History logging moved to new session 319
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 362, in __init__
#     self.__connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 605, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 599, in __connect
#     connection = pool._invoke_creator(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/create.py", line 578, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/default.py", line 584, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 353, in __init__
#     self.connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 633, in connect
#     self._request_authentication()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 907, in _request_authentication
#     auth_packet = self._read_packet()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.OperationalError: (1045, "Access denied for user 'root'@'localhost' (using password: NO)")
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-b8a1bd42c923>", line 1, in <module>
#     df = pd.read_sql_table('customers', engine, columns=["name"])
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pandas/io/sql.py", line 242, in read_sql_table
#     meta.reflect(only=[table_name], views=True)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/sql/schema.py", line 4656, in reflect
#     with inspection.inspect(bind)._inspection_context() as insp:
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/inspection.py", line 64, in inspect
#     ret = reg(subject)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py", line 182, in _engine_insp
#     return Inspector._construct(Inspector._init_engine, bind)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py", line 117, in _construct
#     init(self, bind)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/reflection.py", line 128, in _init_engine
#     engine.connect().close()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3096, in connect
#     return self._connection_cls(self, close_with_result=close_with_result)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 92, in __init__
#     else engine.raw_connection()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3175, in raw_connection
#     return self._wrap_pool_connect(self.pool.connect, _connection)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3146, in _wrap_pool_connect
#     e, dialect, self
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 2005, in _handle_dbapi_exception_noconnection
#     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/base.py", line 3142, in _wrap_pool_connect
#     return fn()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 761, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 362, in __init__
#     self.__connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 605, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/langhelpers.py", line 72, in __exit__
#     with_traceback=exc_tb,
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/util/compat.py", line 211, in raise_
#     raise exception
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/pool/base.py", line 599, in __connect
#     connection = pool._invoke_creator(self)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/create.py", line 578, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/sqlalchemy/engine/default.py", line 584, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 353, in __init__
#     self.connect()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 633, in connect
#     self._request_authentication()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 907, in _request_authentication
#     auth_packet = self._read_packet()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# sqlalchemy.exc.OperationalError: (pymysql.err.OperationalError) (1045, "Access denied for user 'root'@'localhost' (using password: NO)")
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'OperationalError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3282, in run_ast_nodes
#     self.showtraceback()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1211, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory

# %% [markdown]
# <h3 style="color:purple">Join two tables and read them in a dataframe using <span style="color:blue">read_sql_query</span></h3>

# %%
df = pd.read_sql_query("select id,name from customers",engine)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-ff553112af17> in <module>
# ----> 1 df = pd.read_sql_query("select id,name from customers",engine='openpyxl')
#       2 df
#
# TypeError: read_sql_query() got an unexpected keyword argument 'engine'

# %%
query = '''
 SELECT customers.name, customers.phone_number, orders.name, orders.amount
 FROM customers INNER JOIN orders
 ON customers.id=orders.customer_id
'''
df = pd.read_sql_query(query,engine)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4e9ef42a0ee7> in <module>
#       4  ON customers.id=orders.customer_id
#       5 '''
# ----> 6 df = pd.read_sql_query(query,engine)
#       7 df
#
# NameError: name 'engine' is not defined

# %% [markdown]
# <h3 style="color:purple"><span style="color:blue">read_sql</span> is a wrapper around read_sql_query and read_sql_table</h3>

# %%
query = '''
 SELECT customers.name, customers.phone_number, orders.name, orders.amount
 FROM customers INNER JOIN orders
 ON customers.id=orders.customer_id
'''
pd.read_sql(query,engine)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-bd7fce677cb9> in <module>
#       4  ON customers.id=orders.customer_id
#       5 '''
# ----> 6 pd.read_sql(query,engine)
#
# NameError: name 'engine' is not defined

# %%
pd.read_sql("customers",engine)
# Out:
#    id             name phone_number
# 0   1           Donald   7326784567
# 1   2             Bill   6573489999
# 2   3             Modi   4567895646
# 3  10     rafael nadal   4567895647
# 4  11  maria sharapova    434534545
# 5  12   vladimir putin     89345345
# 6  13      kim un jong    123434456
# 7  14       jeff bezos    934534543
# 8  15     rahul gandhi     44324222

# %% [markdown]
# <h3 style="color:purple">Write to mysql database using <span style="color:blue">to_sql</span></h3>

# %%
df = pd.read_csv("customers.csv")
df
# Out:
#      Customer Name  Customer Phone
# 0     rafael nadal      4567895647
# 1  maria sharapova       434534545
# 2   vladimir putin        89345345
# 3      kim un jong       123434456
# 4       jeff bezos       934534543
# 5     rahul gandhi        44324222

# %%
df.rename(columns={
    'Customer Name': 'name',
    'Customer Phone': 'phone_number'
}, inplace=True)
df
# Out:
#               name  phone_number
# 0     rafael nadal    4567895647
# 1  maria sharapova     434534545
# 2   vladimir putin      89345345
# 3      kim un jong     123434456
# 4       jeff bezos     934534543
# 5     rahul gandhi      44324222

# %%
df.to_sql(
    name='customers', # database table name
    con=engine,
    if_exists='append',
    index=False
)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-bc6f175c8de7>", line 1, in <module>
#     df.to_sql(
# NameError: name 'df' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-bc6f175c8de7>", line 1, in <module>
#     df.to_sql(
# NameError: name 'df' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-bc6f175c8de7>", line 1, in <module>
#     df.to_sql(
# NameError: name 'df' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3282, in run_ast_nodes
#     self.showtraceback()
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1211, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/usr/lib/python3.6/inspect.py", line 725, in getmodule
#     file = getabsfile(object, _filename)
#   File "/usr/lib/python3.6/inspect.py", line 709, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/home/vins/Workspace/Py/python/venv/lib/python3.6/posixpath.py", line 383, in abspath
#     cwd = os.getcwd()
# FileNotFoundError: [Errno 2] No such file or directory
# ERROR! Session/line number was not unique in database. History logging moved to new session 320

# %% [markdown]
# **to_sql has different parameters such as chunksize which allows to write data in chunks. This is useful when
# size of dataframe is huge**
