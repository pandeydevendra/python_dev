# %%
import pandas as pd
import numpy as np
import math

# %%
year = range(1800,2022, 1)
year
# Out:
# range(1800, 2022)

# %%
type(year)
# Out:
# range

# %%
year_list = list(year)
year_list
# Out:
# [1800,
#  1801,
#  1802,
#  1803,
#  1804,
#  1805,
#  1806,
#  1807,
#  1808,
#  1809,
#  1810,
#  1811,
#  1812,
#  1813,
#  1814,
#  1815,
#  1816,
#  1817,
#  1818,
#  1819,
#  1820,
#  1821,
#  1822,
#  1823,
#  1824,
#  1825,
#  1826,
#  1827,
#  1828,
#  1829,
#  1830,
#  1831,
#  1832,
#  1833,
#  1834,
#  1835,
#  1836,
#  1837,
#  1838,
#  1839,
#  1840,
#  1841,
#  1842,
#  1843,
#  1844,
#  1845,
#  1846,
#  1847,
#  1848,
#  1849,
#  1850,
#  1851,
#  1852,
#  1853,
#  1854,
#  1855,
#  1856,
#  1857,
#  1858,
#  1859,
#  1860,
#  1861,
#  1862,
#  1863,
#  1864,
#  1865,
#  1866,
#  1867,
#  1868,
#  1869,
#  1870,
#  1871,
#  1872,
#  1873,
#  1874,
#  1875,
#  1876,
#  1877,
#  1878,
#  1879,
#  1880,
#  1881,
#  1882,
#  1883,
#  1884,
#  1885,
#  1886,
#  1887,
#  1888,
#  1889,
#  1890,
#  1891,
#  1892,
#  1893,
#  1894,
#  1895,
#  1896,
#  1897,
#  1898,
#  1899,
#  1900,
#  1901,
#  1902,
#  1903,
#  1904,
#  1905,
#  1906,
#  1907,
#  1908,
#  1909,
#  1910,
# ...

# %%
type(year_list)
# Out:
# list

# %%
year_series = pd.Series(year_list)
year_series
# Out:
# 0      1800
# 1      1801
# 2      1802
# 3      1803
# 4      1804
#        ...
# 217    2017
# 218    2018
# 219    2019
# 220    2020
# 221    2021
# Length: 222, dtype: int64

# %%
year_series.shape
# Out:
# (222,)

# %%
type(year_series)
# Out:
# pandas.core.series.Series

# %%
df_year = pd.DataFrame(year_list)

# %%
df_year
# Out:
#         0
# 0    1800
# 1    1801
# 2    1802
# 3    1803
# 4    1804
# ..    ...
# 217  2017
# 218  2018
# 219  2019
# 220  2020
# 221  2021
#
# [222 rows x 1 columns]

# %%
df_year.shape
# Out:
# (222, 1)

# %%
type(df_year)
# Out:
# pandas.core.frame.DataFrame

# %%
df_year.rename({0: "year"}, axis = "columns", inplace = True) 
df_year
# Out:
#      year
# 0    1800
# 1    1801
# 2    1802
# 3    1803
# 4    1804
# ..    ...
# 217  2017
# 218  2018
# 219  2019
# 220  2020
# 221  2021
#
# [222 rows x 1 columns]

# %%
year_df = pd.DataFrame(year_series)
year_df
# Out:
#         0
# 0    1800
# 1    1801
# 2    1802
# 3    1803
# 4    1804
# ..    ...
# 217  2017
# 218  2018
# 219  2019
# 220  2020
# 221  2021
#
# [222 rows x 1 columns]

# %%
type(year_df)
# Out:
# pandas.core.frame.DataFrame

# %%
year_df.shape
# Out:
# (222, 1)

# %%
df = pd.DataFrame(pd.Series(range(1800, 2023, 1)))
df
# Out:
#         0
# 0    1800
# 1    1801
# 2    1802
# 3    1803
# 4    1804
# ..    ...
# 218  2018
# 219  2019
# 220  2020
# 221  2021
# 222  2022
#
# [223 rows x 1 columns]

# %%
df.rename({0:"year"}, axis= "columns", inplace = True)

# %%
df
# Out:
#      year
# 0    1800
# 1    1801
# 2    1802
# 3    1803
# 4    1804
# ..    ...
# 218  2018
# 219  2019
# 220  2020
# 221  2021
# 222  2022
#
# [223 rows x 1 columns]

# %%
odd_even = []
def add_odd_even_column(df):    
    for y in df["year"]:
        if y%2 == 0:
            odd_even.append("even")
        else:
            odd_even.append("odd")
    odd_even_series = pd.Series(odd_even)
    return df.assign(odd_even = odd_even_series)

df_year_odd_even = add_odd_even_column(df_year)
df_year_odd_even
# Out:
#      year odd_even
# 0    1800     even
# 1    1801      odd
# 2    1802     even
# 3    1803      odd
# 4    1804     even
# ..    ...      ...
# 217  2017      odd
# 218  2018     even
# 219  2019      odd
# 220  2020     even
# 221  2021      odd
#
# [222 rows x 2 columns]

# %%
leap_year = []
def check_leap_year(df):
    for y in df["year"]:
        if ((y%4 == 0) & (y%100 != 0) | (y%400 == 0)):
            leap_year.append("yes")
        else: 
            leap_year.append("no")
    
    return df.assign(leap_year = pd.DataFrame(leap_year))

df_year_leap_odd_even = check_leap_year(df_year_odd_even)
df_year_leap_odd_even
# Out:
#      year odd_even leap_year
# 0    1800     even        no
# 1    1801      odd        no
# 2    1802     even        no
# 3    1803      odd        no
# 4    1804     even       yes
# ..    ...      ...       ...
# 217  2017      odd        no
# 218  2018     even        no
# 219  2019      odd        no
# 220  2020     even       yes
# 221  2021      odd        no
#
# [222 rows x 3 columns]

# %%
square_result = []
def perfect_square_year(df):
    for y in df["year"]:
        for i in range(y//2 + 1):
            if y == i*i:
                square_result.append(i)
                break
        else:
            square_result.append("no")
    return square_result
                
            
        
square_result_list = perfect_square_year(df_year_leap_odd_even)
df_year_all = df_year_leap_odd_even.assign(perfect_square = square_result_list)
df_year_all
# Out:
#      year odd_even leap_year perfect_square
# 0    1800     even        no             no
# 1    1801      odd        no             no
# 2    1802     even        no             no
# 3    1803      odd        no             no
# 4    1804     even       yes             no
# ..    ...      ...       ...            ...
# 217  2017      odd        no             no
# 218  2018     even        no             no
# 219  2019      odd        no             no
# 220  2020     even       yes             no
# 221  2021      odd        no             no
#
# [222 rows x 4 columns]

# %%
df_year_all[df_year_all["leap_year"] == "yes"]
# Out:
#      year odd_even leap_year perfect_square
# 4    1804     even       yes             no
# 8    1808     even       yes             no
# 12   1812     even       yes             no
# 16   1816     even       yes             no
# 20   1820     even       yes             no
# 24   1824     even       yes             no
# 28   1828     even       yes             no
# 32   1832     even       yes             no
# 36   1836     even       yes             no
# 40   1840     even       yes             no
# 44   1844     even       yes             no
# 48   1848     even       yes             no
# 52   1852     even       yes             no
# 56   1856     even       yes             no
# 60   1860     even       yes             no
# 64   1864     even       yes             no
# 68   1868     even       yes             no
# 72   1872     even       yes             no
# 76   1876     even       yes             no
# 80   1880     even       yes             no
# ...

# %%
df_year_all[df_year_all["leap_year"] == "yes"].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 4 to 220
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            54 non-null     int64
#  1   odd_even        54 non-null     object
#  2   leap_year       54 non-null     object
#  3   perfect_square  54 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 2.1+ KB

# %%
len(df_year_all[df_year_all["leap_year"] == "yes"])
# Out:
# 54

# %%
df_year_all[df_year_all["perfect_square"] == "no"]
# Out:
#      year odd_even leap_year perfect_square
# 0    1800     even        no             no
# 1    1801      odd        no             no
# 2    1802     even        no             no
# 3    1803      odd        no             no
# 4    1804     even       yes             no
# ..    ...      ...       ...            ...
# 217  2017      odd        no             no
# 218  2018     even        no             no
# 219  2019      odd        no             no
# 220  2020     even       yes             no
# 221  2021      odd        no             no
#
# [220 rows x 4 columns]

# %%
df_year_all[-[df_year_all[df_year_all["perfect_square"] == "no"]]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-166-e91c3b3e139f> in <module>
# ----> 1 df_year_all[-[df_year_all[df_year_all["perfect_square"] == "no"]]]
#
# TypeError: bad operand type for unary -: 'list'

# %%
df_year_all[(df_year_all["odd_even"] == "odd") & (df_year_all["leap_year"] == "yes")]
# Out:
# Empty DataFrame
# Columns: [year, odd_even, leap_year, perfect_square]
# Index: []

# %%
df_year_all[(df_year_all["odd_even"] == "odd") & (df_year_all["leap_year"] == "yes")].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            0 non-null      int64
#  1   odd_even        0 non-null      object
#  2   leap_year       0 non-null      object
#  3   perfect_square  0 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 0.0+ bytes

# %%
df_year_all[df_year_all["perfect_square"] != "no"]
# Out:
#      year odd_even leap_year perfect_square
# 49   1849      odd        no             43
# 136  1936     even       yes             44
