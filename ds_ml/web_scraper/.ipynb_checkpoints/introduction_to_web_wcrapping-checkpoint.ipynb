# %%
# imports
## requests to make api calls to the websites

import requests

# %%
# website address
# res object
web_address = 'https://web.learncodeonline.in/'
res = requests.get(web_address)

# %%
res
# Out:
# <Response [200]>

# %%
type(res)
# Out:
# requests.models.Response

# %%
res.text
# Out:
# '<!DOCTYPE html><html><head><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><title>LearnCodeOnline</title><meta name="description" content="Your home to learn programming"/><link rel="icon" href="https://learnyst.s3.amazonaws.com/assets/schools/2410/resources/images/logo_lco_t17sd.png"/><meta name="next-head-count" content="5"/><link rel="preload" href="/_next/static/css/b17f60f8c91c7ece.css" as="style"/><link rel="stylesheet" href="/_next/static/css/b17f60f8c91c7ece.css" data-n-g=""/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="/_next/static/chunks/polyfills-5cd94c89d3acac5f.js"></script><script src="/_next/static/chunks/webpack-d8d4955b0b3f78c5.js" defer=""></script><script src="/_next/static/chunks/framework-91d7f78b5b4003c8.js" defer=""></script><script src="/_next/static/chunks/main-47291ab356643a93.js" defer=""></script><script src="/_next/static/chunks/pages/_app-efc6fa9142c6b683.js" defer=""></script><script src="/_next/stati
# ...

# %%
res.url
# Out:
# 'https://web.learncodeonline.in/'

# %%
res.content
# Out:
# b'<!DOCTYPE html><html><head><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><title>LearnCodeOnline</title><meta name="description" content="Your home to learn programming"/><link rel="icon" href="https://learnyst.s3.amazonaws.com/assets/schools/2410/resources/images/logo_lco_t17sd.png"/><meta name="next-head-count" content="5"/><link rel="preload" href="/_next/static/css/b17f60f8c91c7ece.css" as="style"/><link rel="stylesheet" href="/_next/static/css/b17f60f8c91c7ece.css" data-n-g=""/><noscript data-n-css=""></noscript><script defer="" nomodule="" src="/_next/static/chunks/polyfills-5cd94c89d3acac5f.js"></script><script src="/_next/static/chunks/webpack-d8d4955b0b3f78c5.js" defer=""></script><script src="/_next/static/chunks/framework-91d7f78b5b4003c8.js" defer=""></script><script src="/_next/static/chunks/main-47291ab356643a93.js" defer=""></script><script src="/_next/static/chunks/pages/_app-efc6fa9142c6b683.js" defer=""></script><script src="/_next/stat
# ...

# %% [markdown]
# ## Beautiful Soup 4:
# Beautiful Soup is a Python library for pulling data out of HTML and XML files.
# It works with your favorite parser to provide idiomatic ways of navigating, searching, and modifying the parse tree.
# It commonly saves programmers hours or days of work.

# %%
# import bs4
import bs4

# %%
from bs4 import BeautifulSoup

# %%
# create a soup object from a response object
soup = BeautifulSoup(res.text, 'html')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
text_title = soup.select('title')

# %%
text_title
# Out:
# [<title>LearnCodeOnline</title>]

# %%
text_title[0].getText
# Out:
# <bound method PageElement.get_text of <title>LearnCodeOnline</title>>

# %%
text_title[0].getText()
# Out:
# 'LearnCodeOnline'

# %%
type(text_title)
# Out:
# bs4.element.ResultSet

# %%
text_title[0].name
# Out:
# 'title'

# %%
text_title[0].string
# Out:
# 'LearnCodeOnline'

# %%
soup.title
# Out:
# <title>LearnCodeOnline</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.string
# Out:
# 'LearnCodeOnline'

# %%
soup.title.parent.name
# Out:
# 'head'

# %%
soup.p
# Out:
# <p class="font-body font-regular text-[8px] rounded-xl pl-[2.5px] mt-[1px] text-[#000000]">Pro</p>

# %%
soup.p['class']
# Out:
# ['font-body',
#  'font-regular',
#  'text-[8px]',
#  'rounded-xl',
#  'pl-[2.5px]',
#  'mt-[1px]',
#  'text-[#000000]']

# %%
soup.a
# Out:
# <a class="cursor-pointer text-[#F2F2F2] hover:text-[#8E55FF] font-body font-regular text-[14px] no-underline mr-[20px]" href="https://courses.learncodeonline.in/learn">Courses</a>

# %%
soup.find_all('a')
# Out:
# [<a class="cursor-pointer text-[#F2F2F2] hover:text-[#8E55FF] font-body font-regular text-[14px] no-underline mr-[20px]" href="https://courses.learncodeonline.in/learn">Courses</a>,
#  <a class="cursor-pointer text-[#F2F2F2] hover:text-[#8E55FF] font-body font-regular text-[14px] no-underline mr-[30px] relative" href="https://pro.learncodeonline.in/learn">LCO Pro<span class="absolute w-[31px] h-[14px] bg-[#E8B324] font-body font-semibold rounded-xl pl-[6.5px] left-5 -top-3 ml-[3px] text-[#000000]"><p class="font-body font-regular text-[8px] rounded-xl pl-[2.5px] mt-[1px] text-[#000000]">Pro</p></span></a>,
#  <a class="no-underline text-[#F2F2F2] hover:text-[#8E55FF] space-x-3" href="/Help" style="margin-right:20px">Help</a>,
#  <a class="no-underline text-[#F2F2F2] hover:text-[#8E55FF]" href="">Login/Signup</a>,
#  <a class="no-underline text-[#FBFAFF] hover:text-[#FBFAFF]" href="/mobile-app">LCO App</a>,
# ...

# %%
soup.find(id="link3")

# %%
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html>\n <head>\n  <meta content="width=device-width" name="viewport"/>\n  <meta charset="utf-8"/>\n  <title>\n   LearnCodeOnline\n  </title>\n  <meta content="Your home to learn programming" name="description"/>\n  <link href="https://learnyst.s3.amazonaws.com/assets/schools/2410/resources/images/logo_lco_t17sd.png" rel="icon"/>\n  <meta content="5" name="next-head-count"/>\n  <link as="style" href="/_next/static/css/b17f60f8c91c7ece.css" rel="preload"/>\n  <link data-n-g="" href="/_next/static/css/b17f60f8c91c7ece.css" rel="stylesheet"/>\n  <noscript data-n-css="">\n  </noscript>\n  <script defer="" nomodule="" src="/_next/static/chunks/polyfills-5cd94c89d3acac5f.js">\n  </script>\n  <script defer="" src="/_next/static/chunks/webpack-d8d4955b0b3f78c5.js">\n  </script>\n  <script defer="" src="/_next/static/chunks/framework-91d7f78b5b4003c8.js">\n  </script>\n  <script defer="" src="/_next/static/chunks/main-47291ab356643a93.js">\n  </script>\n  <script defer="" sr
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="width=device-width" name="viewport"/>
#   <meta charset="utf-8"/>
#   <title>
#    LearnCodeOnline
#   </title>
#   <meta content="Your home to learn programming" name="description"/>
#   <link href="https://learnyst.s3.amazonaws.com/assets/schools/2410/resources/images/logo_lco_t17sd.png" rel="icon"/>
#   <meta content="5" name="next-head-count"/>
#   <link as="style" href="/_next/static/css/b17f60f8c91c7ece.css" rel="preload"/>
#   <link data-n-g="" href="/_next/static/css/b17f60f8c91c7ece.css" rel="stylesheet"/>
#   <noscript data-n-css="">
#   </noscript>
#   <script defer="" nomodule="" src="/_next/static/chunks/polyfills-5cd94c89d3acac5f.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/webpack-d8d4955b0b3f78c5.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/framework-91d7f78b5b4003c8.js">
#   </script>
#   <script defer="" src="/_next/static/chunks/main-47291ab356643a93.js">
#   </script>
# ...
