# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/home/vins/Workspace/Py/data_files/web_scrap/lqv_data/googleplaystore.csv')

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df_lqv = df[['App','Last Updated', 'Installs', 'Rating', 'Reviews', 'Type']]
df_lqv
# Out:
#                                                      App      Last Updated  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook   January 7, 2018
# 1                                    Coloring book moana  January 15, 2018
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...    August 1, 2018
# 3                                  Sketch - Draw & Paint      June 8, 2018
# 4                  Pixel Draw - Number Art Coloring Book     June 20, 2018
# ...                                                  ...               ...
# 10836                                   Sya9a Maroc - FR     July 25, 2017
# 10837                   Fr. Mike Schmitz Audio Teachings      July 6, 2018
# 10838                             Parkinson Exercices FR  January 20, 2017
# 10839                      The SCP Foundation DB fr nn5n  January 19, 2015
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology     July 25, 2018
#
#           Installs  Rating Reviews  Type
# ...

# %%
df_lqv.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df_lqv['Installs'] = df_lqv['Installs'].str.replace('+', '')
# Out:
# /home/vins/virtenv/py_dev/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## df_lqv['Installs'] = df_lqv['Installs'].astype(float)

# %%
df_lqv
# Out:
#                                                      App      Last Updated  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook   January 7, 2018
# 1                                    Coloring book moana  January 15, 2018
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...    August 1, 2018
# 3                                  Sketch - Draw & Paint      June 8, 2018
# 4                  Pixel Draw - Number Art Coloring Book     June 20, 2018
# ...                                                  ...               ...
# 10836                                   Sya9a Maroc - FR     July 25, 2017
# 10837                   Fr. Mike Schmitz Audio Teachings      July 6, 2018
# 10838                             Parkinson Exercices FR  January 20, 2017
# 10839                      The SCP Foundation DB fr nn5n  January 19, 2015
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology     July 25, 2018
#
#          Installs  Rating Reviews  Type
# ...

# %%
df_original = df_lqv.sort_values('Installs', ascending = False, ignore_index=True)
df_original[:100]
# Out:
#                                                   App       Last Updated  \
# 0             Life Made WI-Fi Touchscreen Photo Frame             1.0.19
# 1         UC Browser - Fast Download Private & Secure     August 2, 2018
# 2                         LINE: Free Calls & Messages      July 26, 2018
# 3                        Flipboard: News For Our Time     August 3, 2018
# 4                                         Cloud Print       May 23, 2018
# ..                                                ...                ...
# 95  Cougar Dating Life : Date Older Women Sugar Mummy       July 3, 2018
# 96                     Best Friends Dress Up & Makeup  September 9, 2015
# 97                           VZ Navigator for Tablets   January 22, 2018
# 98                               Stranger Chat & Date       June 6, 2018
# 99                                       Alzashop.com     August 3, 2018
#
#        Installs  Rating   Reviews  Type
# 0          Free    19.0      3.0M     0
# ...

# %%
df_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   App           10841 non-null  object
#  1   Last Updated  10841 non-null  object
#  2   Installs      10841 non-null  object
#  3   Rating        9367 non-null   float64
#  4   Reviews       10841 non-null  object
#  5   Type          10840 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 508.3+ KB

# %%
df_lqv['Installs'] = pd.to_numeric(df_lqv['Installs'], errors='coerce').fillna(0).astype(np.int64)
# Out:
# /home/vins/virtenv/py_dev/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_lqv.describe()
# Out:
#            Installs       Rating
# count  10841.000000  9367.000000
# mean      23.197768     4.193338
# std       88.243039     0.537431
# min        0.000000     1.000000
# 25%        0.000000     4.000000
# 50%        0.000000     4.300000
# 75%        0.000000     4.500000
# max      500.000000    19.000000

# %%
df_lqv['Reviews'] = df_lqv['Reviews'].str.replace('M', "")
# Out:
# /home/vins/virtenv/py_dev/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_lqv['Reviews'] = pd.to_numeric(df_lqv['Reviews'], errors='coerce').fillna(0).astype(np.int64)
# Out:
# /home/vins/virtenv/py_dev/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_lqv.describe()
# Out:
#            Installs       Rating       Reviews
# count  10841.000000  9367.000000  1.084100e+04
# mean      23.197768     4.193338  4.441119e+05
# std       88.243039     0.537431  2.927629e+06
# min        0.000000     1.000000  0.000000e+00
# 25%        0.000000     4.000000  3.800000e+01
# 50%        0.000000     4.300000  2.094000e+03
# 75%        0.000000     4.500000  5.476800e+04
# max      500.000000    19.000000  7.815831e+07

# %%
df_lqv.rename(columns = {'App': 'App name', 'Last Updated': 'Last update', 'Installs': 'Number of downloads', 'Rating': 'Overall Rating', 'Reviews': 'All reviews','Type': 'Pricing'}, index = None, inplace = True)
# Out:
# /home/vins/virtenv/py_dev/lib/python3.6/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_lqv
# Out:
#                                                 App name       Last update  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook   January 7, 2018
# 1                                    Coloring book moana  January 15, 2018
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...    August 1, 2018
# 3                                  Sketch - Draw & Paint      June 8, 2018
# 4                  Pixel Draw - Number Art Coloring Book     June 20, 2018
# ...                                                  ...               ...
# 10836                                   Sya9a Maroc - FR     July 25, 2017
# 10837                   Fr. Mike Schmitz Audio Teachings      July 6, 2018
# 10838                             Parkinson Exercices FR  January 20, 2017
# 10839                      The SCP Foundation DB fr nn5n  January 19, 2015
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology     July 25, 2018
#
#        Number of downloads  Overall Rating  All reviews Pricing
# ...

# %%
df_lqv_001 = df_lqv.sort_values('Number of downloads', ascending = False, ignore_index=True)
df_lqv_001
# Out:
#                                             App name      Last update  \
# 0                                    SnakeBite911 ER  October 9, 2017
# 1                      HD Wallpapers Volvo FH Trucks    June 21, 2016
# 2                     AZ Immune Related AEManagement     May 24, 2018
# 3                                 EP Search and Find     May 27, 2015
# 4                              A-Z Screen Recorder -    July 23, 2018
# ...                                              ...              ...
# 10836                     Real time Weather Forecast   March 26, 2018
# 10837                                   METEO FRANCE    July 13, 2018
# 10838                   APE Weather ( Live Forecast)     July 3, 2018
# 10839    Live Weather & Daily Local Weather Forecast    July 17, 2018
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology    July 25, 2018
#
#        Number of downloads  Overall Rating  All reviews Pricing
# ...

# %%
df_lqv.describe()
# Out:
#        Number of downloads  Overall Rating   All reviews
# count         10841.000000     9367.000000  1.084100e+04
# mean             23.197768        4.193338  4.441119e+05
# std              88.243039        0.537431  2.927629e+06
# min               0.000000        1.000000  0.000000e+00
# 25%               0.000000        4.000000  3.800000e+01
# 50%               0.000000        4.300000  2.094000e+03
# 75%               0.000000        4.500000  5.476800e+04
# max             500.000000       19.000000  7.815831e+07

# %%
df_lqv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   App name             10841 non-null  object
#  1   Last update          10841 non-null  object
#  2   Number of downloads  10841 non-null  int64
#  3   Overall Rating       9367 non-null   float64
#  4   All reviews          10841 non-null  int64
#  5   Pricing              10840 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 508.3+ KB

# %%
#df_lqv_001[df_lqv_001['Number of downloads' >= 100]]

# %%
df_lqv_001[:500]
# Out:
#                            App name        Last update  Number of downloads  \
# 0                   SnakeBite911 ER    October 9, 2017                  500
# 1     HD Wallpapers Volvo FH Trucks      June 21, 2016                  500
# 2    AZ Immune Related AEManagement       May 24, 2018                  500
# 3                EP Search and Find       May 27, 2015                  500
# 4             A-Z Screen Recorder -      July 23, 2018                  500
# ..                              ...                ...                  ...
# 495                    VAT check CY       May 18, 2013                  100
# 496                   The CJ Rubric   December 5, 2017                  100
# 497        DM Storage (for twitter)  November 26, 2014                  100
# 498           NOMISMA.com.cy by FMW       May 29, 2016                  100
# 499       Ad Removal: thereisonlywe        May 3, 2014                  100
#
#      Overall Rating  All reviews Pricing
# ...

# %%
df_lqv_001[:100] = df_lqv.sort_values('Number of downloads', ascending = False, ignore_index=True)

# %%
df_original['Installs'] = pd.to_numeric(df_lqv['Installs'], errors='coerce').astype(np.int64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-127-4a628b2dd7a3> in <module>
# ----> 1 df_original['Installs'] = pd.to_numeric(df_lqv['Installs'], errors='coerce').astype(np.int64)
#
# ~/virtenv/py_dev/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~/virtenv/py_dev/lib/python3.6/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
# ...

# %%
df_original[1:200]
# Out:
#                                                 App       Last Updated  \
# 1       UC Browser - Fast Download Private & Secure     August 2, 2018
# 2                       LINE: Free Calls & Messages      July 26, 2018
# 3                      Flipboard: News For Our Time     August 3, 2018
# 4                                       Cloud Print       May 23, 2018
# 5                      Gboard - the Google Keyboard      July 31, 2018
# ..                                              ...                ...
# 195                  MSN Sports - Scores & Schedule       July 5, 2018
# 196                   Ad Detect Plugin - Handy Tool  December 28, 2015
# 197  EliteSingles – Dating for Single Professionals      July 31, 2018
# 198                    Shoot`Em Down: Shooting game    August 12, 2017
# 199                  Bt Notifier -Smartwatch notice       May 23, 2017
#
#         Installs  Rating   Reviews  Type
# 1    500,000,000     4.5  17714850  Free
# ...

# %%
df_original[1:201].to_csv('/home/vins/Workspace/Py/data_files/web_scrap/lqv_data/top_200_apps.csv')

# %%
df_original[1:201].to_excel('/home/vins/Workspace/Py/data_files/web_scrap/lqv_data/top_200_apps.xlsx')
